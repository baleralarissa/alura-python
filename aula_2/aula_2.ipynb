# %% [markdown]
# ## Aula 2 - Manipulando dados no Python

# %% [markdown]
# ### Coleta e amostragem de dados

# %% [markdown]
# #### Questão 1
# Crie um programa que solicite à pessoa usuária digitar seu nome, e imprima “Olá, [nome]!”.

# %%
nome = input("Digite seu nome: ")

print(f'Olá {nome}')
# Out:
# Olá Lari

# %% [markdown]
# #### Questão 2
# Crie um programa que solicite à pessoa usuária digitar seu nome e idade, e imprima “Olá, [nome], você tem [idade] anos.”.

# %%
import datetime

nome = input("Digite seu nome: ")
ano = int(input("Digite o ano de nascimento: "))

ano_atual = datetime.date.today()
ano_atual_ano = ano_atual.year
idade = ano_atual_ano - ano

print(f'Olá {nome}, você tem {idade} anos')
# Out:
# Olá Lari, você tem 26 anos

# %% [markdown]
# #### Questão 3
# Crie um programa que solicite à pessoa usuária digitar seu nome, idade e altura em metros, e imprima “Olá, [nome], você tem [idade] anos e mede [altura] metros!”.

# %%
import datetime

nome = input("Digite seu nome: ")
ano = int(input("Digite o ano de nascimento: "))
altura = float(input("Digite a sua altura: "))

ano_atual = datetime.date.today()
ano_atual_ano = ano_atual.year
idade = ano_atual_ano - ano

print(f'Olá {nome}, você tem {idade} anos e mede {altura}')
# Out:
# Olá Lari, você tem 26 anos e mede 1.67

# %% [markdown]
# ### Calculadora com operadores

# %% [markdown]
# #### Questão 1
#
# Crie um programa que solicite dois valores numéricos à pessoa usuária e imprima a soma dos dois valores.

# %%
var1 = float(input("Valor 1: "))
var2 = float(input("Valor 2: "))


def soma(var1, var2):
    valores = []

    valores.append(var1)
    valores.append(var2)

    resultado = sum(valores)
    print(resultado)


    
soma(var1, var2)
# Out:
# 10.0

# %% [markdown]
# #### Questão 2
# Crie um programa que solicite três valores numéricos à pessoa usuária e imprima a soma dos três valores.

# %%
var1 = float(input("Valor 1: "))
var2 = float(input("Valor 2: "))
var3 = float(input("Valor 3: "))

def soma(var1, var2, var3):
    valores = []

    valores.append(var1)
    valores.append(var2)
    valores.append(var2)

    resultado = sum(valores)
    print(f'Você digitou os valores: {var1}, {var2}, {var3} e o resultado é {resultado}')


    
soma(var1, var2, var3)
# Out:
# Você digitou os valores: 25.0, 69.0, 3.0 e o resultado é 163.0

# %% [markdown]
# #### Questão 3
# Crie um programa que solicite dois valores numéricos à pessoa usuária e imprima a subtração do primeiro pelo o segundo valor.

# %%
var1 = float(input("Valor 1: "))
var2 = float(input("Valor 2: "))


def sub(var1, var2):
    valores = []

    valores.append(var1)
    valores.append(var2)

    resultado = var1 - var2
    print(f'Você digitou os valores: {var1}, {var2} e o resultado é {resultado}')


    
sub(var1, var2)
# Out:
# Você digitou os valores: 10.0, 5.0 e o resultado é 5.0

# %% [markdown]
# #### Questão 4
#
# Crie um programa que solicite dois valores numéricos à pessoa usuária e imprima a multiplicação dos dois valores.

# %%
var1 = float(input("Valor 1: "))
var2 = float(input("Valor 2: "))


def multiply(var1, var2):
    valores = []

    valores.append(var1)
    valores.append(var2)

    resultado = var1 * var2
    print(f'Você digitou os valores: {var1}, {var2} e o resultado é {resultado}')


    
multiply(var1, var2)
# Out:
# Você digitou os valores: 34.0, 67.0 e o resultado é 2278.0

# %% [markdown]
# #### Questão 5
#
# Crie um programa que solicite dois valores numéricos, um numerador e um denominador, e realize a divisão entre os dois valores. Deixe claro que o valor do denominador não pode ser `0`.

# %%
var1 = float(input("Valor 1: "))
var2 = float(input("Valor 2: "))

def div(var1, var2):
    valores = []
    if var2 == 0:
        print('Valor inválido. O número deve ser maior do que 0')
    else:
        valores.append(var1)
        valores.append(var2)

        resultado = var1 / var2
        print(f'Você digitou os valores: {var1}, {var2} e o resultado é {resultado}')

div(var1,var2)
# Out:
# Valor inválido. O número deve ser maior do que 0

# %% [markdown]
# #### Questão 6
#
# Crie um programa que solicite dois valores numéricos, um operador e uma potência, e realize a exponenciação entre esses dois valores.

# %%
var1 = float(input("Valor 1: "))
var2 = float(input("Valor 2: "))


def expo(var1, var2):
    valores = []

    valores.append(var1)
    valores.append(var2)

    resultado = var1 ** var2
    print(f'Você digitou os valores: {var1}, {var2} e o resultado é {resultado}')


    
expo(var1, var2)
# Out:
# Você digitou os valores: 3.0, 3.0 e o resultado é 27.0

# %% [markdown]
# #### Questão 7
# Crie um programa que solicite dois valores numéricos, um numerador e um denominador e realize a divisão inteira entre os dois valores. Deixe claro que o valor do denominador não pode ser `0`.

# %%
var1 = float(input("Valor 1: "))
var2 = float(input("Valor 2: "))

def div_int(var1, var2):
    valores = []
    if var2 == 0:
        print('Valor inválido. O número deve ser maior do que 0')
    else:
        valores.append(var1)
        valores.append(var2)

        resultado = var1 // var2
        print(f'Você digitou os valores: {var1}, {var2} e o resultado é {resultado}')

div_int(var1,var2)
# Out:
# Você digitou os valores: 25.0, 3.0 e o resultado é 8.0

# %% [markdown]
# #### Questão 8
#
# Crie um programa que solicite dois valores numéricos, um numerador e um denominador, e retorne o resto da divisão entre os dois valores. Deixe claro que o valor do denominador não pode ser `0`.

# %%
var1 = float(input("Valor 1: "))
var2 = float(input("Valor 2: "))

def div_int(var1, var2):
    valores = []
    if var2 == 0:
        print('Valor inválido. O número deve ser maior do que 0')
    else:
        valores.append(var1)
        valores.append(var2)

        resultado = var1 % var2
        print(f'Você digitou os valores: {var1}, {var2} e o resultado é {resultado}')

div_int(var1,var2)
# Out:
# Você digitou os valores: 25.0, 3.0 e o resultado é 1.0

# %% [markdown]
# #### Questão 9
#
# Crie um código que solicita 3 notas de um estudante e imprima a média das notas.

# %%
i = 0
notas = int(input("Quantas notas deseja inserir?: "))
valores = []

while i < notas:        
    nota= float(input("Digite o valor da nota: "))
    valores.append(nota)
    print(valores)
    i+= 1

media = round(sum(valores)/len(valores),2)
print(f'As notas inseridas foram {valores} e a média final é {media}')
# Out:
# [10.0]
# [10.0, 5.0]
# [10.0, 5.0, 7.0]
# As notas inseridas foram [10.0, 5.0, 7.0] e a média final é 7.33

# %% [markdown]
# #### Questão 10
#
# Crie um código que calcule e imprima a média ponderada dos números 5, 12, 20 e 15 com pesos respectivamente iguais a 1, 2, 3 e 4.

# %%
numeros = [5, 12, 20, 15]
pesos = [1, 2, 3, 4]

if len(numeros) != len(pesos):
    print("As listas de números e pesos devem ter o mesmo tamanho!")
else:
    soma_produtos = sum(n * p for n, p in zip(numeros, pesos))
    soma_pesos = sum(pesos)
    avg_w = soma_produtos / soma_pesos

    print(f'A média ponderada dos números é: {avg_w}')
# Out:
# A média ponderada dos números é: 14.9

# %% [markdown]
# ## Editando textos

# %% [markdown]
# #### Questão 1
#
# Crie uma variável chamada “`frase`” e atribua a ela uma string de sua escolha. Em seguida, imprima a frase na tela.

# %%
frase = 'Hello World'
print(frase)
# Out:
# Hello World

# %% [markdown]
# #### Questão 2
# Crie um código que solicite uma frase e depois imprima a frase na tela.

# %%
frase = input("Digite uma frase: ")
print(frase)
# Out:
# Hello World

# %% [markdown]
# #### Questão 3
#
# Crie um código que solicite uma frase à pessoa usuária e imprima a mesma frase digitada mas com todas as letras maiúsculas.

# %%
frase = input("Digite uma frase: ")
print(frase.upper())
# Out:
# HELLO WORLD

# %% [markdown]
# #### Questão 4
#
# Crie um código que solicite uma frase à pessoa usuária e imprima a mesma frase digitada mas com todas as letras minúsculas.

# %%
frase = input("Digite uma frase: ")
print(frase.lower())
# Out:
# hello world

# %% [markdown]
# #### Questão 5
#
# Crie uma variável chamada “`frase`” e atribua a ela uma string de sua escolha. Em seguida, imprima a frase sem espaços em branco no início e no fim.

# %%
frase = "  Hello World  "
print(frase.strip())
# Out:
# Hello World

# %% [markdown]
# #### Questão 6
#
# Crie um código que solicite uma frase à pessoa usuária e imprima a mesma frase sem espaços em branco no início e no fim.

# %%
frase = input("Digite uma frase: ")
print(frase.strip())
# Out:
# Hello World

# %% [markdown]
# #### Questão 7
#
#
# Crie um código que solicite uma frase à pessoa usuária e imprima a mesma frase sem espaços em branco no início e no fim e em letras minúsculas.

# %%
frase = input("Digite uma frase: ")
print(frase.strip().lower())
# Out:
# hello world

# %% [markdown]
# #### Questão 8
#
# Crie um código que solicite uma frase à pessoa usuária e imprima a mesma frase com todas as vogais “`e`” trocadas pela letra “`f`”.

# %%
frase = input("Digite uma frase: ")
print(frase.replace('e', 'f'))
# Out:
# Hfllo World

# %% [markdown]
# #### Questão 9
#
#
# Crie um código que solicite uma frase à pessoa usuária e imprima a mesma frase com todas as vogais “`a`” trocadas pela caractere  “`@`”.

# %%
frase = input("Digite uma frase: ")
print(frase.replace('a', chr(64)))
# Out:
# Ol@ Mundo

# %% [markdown]
# #### Questão 10
#
#
# Crie um código que solicite uma frase à pessoa usuária e imprima a mesma frase com todas as consoantes “`s`” trocadas pelo caractere  “`$`”.

# %%
frase = input("Digite uma frase: ")
print(frase.replace('s', chr(36)))
# Out:
# Boa $emana a todo$
